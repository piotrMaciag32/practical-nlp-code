# %% [markdown]
# # In this notebook we show how we can scrap data from webpages using the [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/), a python library.
# <br><br>

# %%
# To install only the requirements of this notebook, uncomment the lines below and run this cell

# ===========================

# !pip install numpy==1.19.5
# !pip install beautifulsoup4==4.6.3

# ===========================
# Out:
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5.zip (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 20.9 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for numpy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1187 lines of output]
#       setup.py:67: RuntimeWarning: NumPy 1.19.5 may not yet support Python 3.10.
#         warnings.warn(
#       Running from numpy source directory.
#       numpy/random/_bounded_integers.pxd.in has not changed
#       numpy/random/_philox.pyx has not changed
#       numpy/random/_bounded_integers.pyx.in has not changed
#       numpy/random/_sfc64.pyx has not changed
#       numpy/random/_mt19937.pyx has not changed
#       numpy/random/bit_generator.pyx has not changed
#       Processing numpy/random/_bounded_integers.pyx
#       numpy/random/mtrand.pyx has not changed
#       numpy/random/_generator.pyx has not changed
#       numpy/random/_pcg64.pyx has not changed
#       numpy/random/_common.pyx has not changed
#       Cythonizing sources
#       blas_opt_info:
#       blas_mkl_info:
#       customize UnixCCompiler
#         libraries mkl_rt not found in ['/Users/piotr/anaconda3/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       blis_info:
#         libraries blis not found in ['/Users/piotr/anaconda3/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       openblas_info:
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64
#
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/var
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/var/folders
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/var/folders/7k
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk
#       compile options: '-c'
#       clang: /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/source.c
#       clang /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/source.o -L/Users/piotr/anaconda3/lib -lopenblas -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp267fl_sk/a.out
#         FOUND:
#           libraries = ['openblas', 'openblas']
#           library_dirs = ['/Users/piotr/anaconda3/lib']
#           language = c
#           define_macros = [('HAVE_CBLAS', None)]
#
#         FOUND:
#           libraries = ['openblas', 'openblas']
#           library_dirs = ['/Users/piotr/anaconda3/lib']
#           language = c
#           define_macros = [('HAVE_CBLAS', None)]
#
#       non-existing path in 'numpy/distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#         libraries mkl_rt not found in ['/Users/piotr/anaconda3/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64
#
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/var
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/var/folders
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/var/folders/7k
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T
#       creating /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg
#       compile options: '-c'
#       clang: /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/source.c
#       clang /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/source.o -L/Users/piotr/anaconda3/lib -lopenblas -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmp73_ayryg/a.out
#         FOUND:
#           libraries = ['openblas', 'openblas']
#           library_dirs = ['/Users/piotr/anaconda3/lib']
#           language = c
#           define_macros = [('HAVE_CBLAS', None)]
#
#         FOUND:
#           libraries = ['openblas', 'openblas']
#           library_dirs = ['/Users/piotr/anaconda3/lib']
#           language = c
#           define_macros = [('HAVE_CBLAS', None)]
#
#       /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-build-env-u5cplk1a/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       Could not locate executable gfortran
#       Could not locate executable f95
#       Could not locate executable f90
#       Could not locate executable f77
#       Could not locate executable xlf90
#       Could not locate executable xlf
#       Could not locate executable ifort
#       Could not locate executable ifc
#       Could not locate executable g77
#       Could not locate executable g95
#       Could not locate executable pgfortran
#       don't know how to compile Fortran code on platform 'posix'
#         adding 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/npymath' to include_dirs.
#       None - nothing done with h_files = ['build/src.macosx-11.1-arm64-3.10/numpy/core/src/npymath/npy_math_internal.h']
#       building library "npysort" sources
#         adding 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/common' to include_dirs.
#       None - nothing done with h_files = ['build/src.macosx-11.1-arm64-3.10/numpy/core/src/common/npy_sort.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/common/npy_partition.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/common/npy_binsearch.h']
#       building library "npyrandom" sources
#       building extension "numpy.core._multiarray_tests" sources
#       building extension "numpy.core._multiarray_umath" sources
#         adding 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath' to include_dirs.
#         adding 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/npymath' to include_dirs.
#         adding 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/common' to include_dirs.
#       numpy.core - nothing done with h_files = ['build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath/funcs.inc', 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath/simd.inc', 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath/loops.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath/matmul.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath/clip.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/npymath/npy_math_internal.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/src/common/templ_common.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/include/numpy/config.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/include/numpy/__multiarray_api.h', 'build/src.macosx-11.1-arm64-3.10/numpy/core/include/numpy/__ufunc_api.h']
#       building extension "numpy.core._umath_tests" sources
#       building extension "numpy.core._rational_tests" sources
#       building extension "numpy.core._struct_ufunc_tests" sources
#       building extension "numpy.core._operand_flag_tests" sources
#       building extension "numpy.fft._pocketfft_internal" sources
#       building extension "numpy.linalg.lapack_lite" sources
#       building extension "numpy.linalg._umath_linalg" sources
#       building extension "numpy.random._mt19937" sources
#       building extension "numpy.random._philox" sources
#       building extension "numpy.random._pcg64" sources
#       building extension "numpy.random._sfc64" sources
#       building extension "numpy.random._common" sources
#       building extension "numpy.random.bit_generator" sources
#       building extension "numpy.random._generator" sources
#       building extension "numpy.random._bounded_integers" sources
#       building extension "numpy.random.mtrand" sources
#       building data_files sources
#       build_src: building npy-pkg config files
#       running build_py
#       creating build/lib.macosx-11.1-arm64-3.10
#       creating build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/conftest.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/version.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/_globals.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/dual.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/_distributor_init.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/ctypeslib.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/matlib.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying numpy/_pytesttester.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       copying build/src.macosx-11.1-arm64-3.10/numpy/__config__.py -> build/lib.macosx-11.1-arm64-3.10/numpy
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/compat
#       copying numpy/compat/py3k.py -> build/lib.macosx-11.1-arm64-3.10/numpy/compat
#       copying numpy/compat/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/compat
#       copying numpy/compat/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/compat
#       copying numpy/compat/_inspect.py -> build/lib.macosx-11.1-arm64-3.10/numpy/compat
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/compat/tests
#       copying numpy/compat/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/compat/tests
#       copying numpy/compat/tests/test_compat.py -> build/lib.macosx-11.1-arm64-3.10/numpy/compat/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/umath.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/fromnumeric.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_dtype.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_add_newdocs.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_methods.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_internal.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_string_helpers.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/multiarray.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_asarray.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/records.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/setup_common.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/memmap.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/overrides.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/getlimits.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_dtype_ctypes.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/defchararray.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/shape_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/machar.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/numeric.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/function_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/einsumfunc.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/umath_tests.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_ufunc_config.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_exceptions.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/numerictypes.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/_type_aliases.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/cversions.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/arrayprint.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       copying numpy/core/code_generators/generate_numpy_api.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_numerictypes.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_scalar_methods.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_scalarmath.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_item_selection.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_machar.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_unicode.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_arrayprint.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_scalarbuffer.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_indexerrors.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_print.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_half.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_mem_overlap.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_shape_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_deprecations.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_errstate.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_records.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_scalarinherit.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_indexing.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_umath.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_numeric.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_function_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_datetime.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test__exceptions.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_extint128.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_umath_complex.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/_locales.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_defchararray.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_conversion_utils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_scalarprint.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_abc.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_ufunc.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_dtype.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_umath_accuracy.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_getlimits.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_einsum.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_api.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_longdouble.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_overrides.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_scalar_ctors.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_multiarray.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_memmap.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_nditer.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_cpu_features.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_protocols.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       copying numpy/core/tests/test_regression.py -> build/lib.macosx-11.1-arm64-3.10/numpy/core/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/unixccompiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/numpy_distribution.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/conv_template.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/cpuinfo.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/ccompiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/msvc9compiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/npy_pkg_config.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/misc_util.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/log.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/line_endings.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/lib2def.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/pathccompiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/system_info.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/core.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/exec_command.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/from_template.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/mingw32ccompiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/extension.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/msvccompiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/intelccompiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying numpy/distutils/_shell_utils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       copying build/src.macosx-11.1-arm64-3.10/numpy/distutils/__config__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/build.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/config_compiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/build_ext.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/config.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/install_headers.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/build_py.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/build_src.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/sdist.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/build_scripts.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/bdist_rpm.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/install_clib.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/build_clib.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/autodist.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/egg_info.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/install.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/develop.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       copying numpy/distutils/command/install_data.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/command
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/gnu.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/compaq.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/intel.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/none.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/nag.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/pg.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/ibm.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/sun.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/nv.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/lahey.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/g95.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/mips.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/hpux.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/environment.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/pathf95.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/absoft.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/vast.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/fcompiler
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_system_info.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_mingw32ccompiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_from_template.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_fcompiler_intel.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_misc_util.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_fcompiler.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_shell_utils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_exec_command.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_npy_pkg_config.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_fcompiler_nagfor.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       copying numpy/distutils/tests/test_fcompiler_gnu.py -> build/lib.macosx-11.1-arm64-3.10/numpy/distutils/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/misc.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/internals.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/creation.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/dispatch.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/constants.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/ufuncs.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/broadcasting.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/basics.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/subclassing.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/indexing.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/byteswapping.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/structured_arrays.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       copying numpy/doc/glossary.py -> build/lib.macosx-11.1-arm64-3.10/numpy/doc
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/cfuncs.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/common_rules.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/crackfortran.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/cb_rules.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/rules.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/f2py2e.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/func2subr.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/__version__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/diagnose.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/capi_maps.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/f90mod_rules.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/f2py_testing.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/use_rules.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/auxfuncs.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       copying numpy/f2py/__main__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_mixed.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_logical.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_assumed_shape.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_common.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_kind.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_array_from_pyobj.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_real.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/util.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_size.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_callback.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_string.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_quoted_character.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_parameter.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_semicolon_split.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_compile_function.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_block_docstring.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_integer.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_character.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_complex.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_crackfortran.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       copying numpy/f2py/tests/test_regression.py -> build/lib.macosx-11.1-arm64-3.10/numpy/f2py/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/fft
#       copying numpy/fft/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/fft
#       copying numpy/fft/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/fft
#       copying numpy/fft/helper.py -> build/lib.macosx-11.1-arm64-3.10/numpy/fft
#       copying numpy/fft/_pocketfft.py -> build/lib.macosx-11.1-arm64-3.10/numpy/fft
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/fft/tests
#       copying numpy/fft/tests/test_pocketfft.py -> build/lib.macosx-11.1-arm64-3.10/numpy/fft/tests
#       copying numpy/fft/tests/test_helper.py -> build/lib.macosx-11.1-arm64-3.10/numpy/fft/tests
#       copying numpy/fft/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/fft/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/_iotools.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/mixins.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/nanfunctions.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/recfunctions.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/histograms.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/scimath.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/_version.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/user_array.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/format.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/twodim_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/financial.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/index_tricks.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/npyio.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/shape_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/stride_tricks.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/utils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/arrayterator.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/function_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/arraysetops.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/arraypad.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/type_check.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/polynomial.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/_datasource.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       copying numpy/lib/ufunclike.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_type_check.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_utils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_twodim_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_polynomial.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test__iotools.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_shape_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_ufunclike.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_index_tricks.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_arrayterator.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test__version.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_io.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_arraysetops.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_function_base.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_arraypad.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_mixins.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_packbits.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test__datasource.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_stride_tricks.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_financial.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_recfunctions.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_nanfunctions.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_format.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_histograms.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       copying numpy/lib/tests/test_regression.py -> build/lib.macosx-11.1-arm64-3.10/numpy/lib/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/linalg
#       copying numpy/linalg/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/linalg
#       copying numpy/linalg/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/linalg
#       copying numpy/linalg/linalg.py -> build/lib.macosx-11.1-arm64-3.10/numpy/linalg
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/linalg/tests
#       copying numpy/linalg/tests/test_linalg.py -> build/lib.macosx-11.1-arm64-3.10/numpy/linalg/tests
#       copying numpy/linalg/tests/test_deprecations.py -> build/lib.macosx-11.1-arm64-3.10/numpy/linalg/tests
#       copying numpy/linalg/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/linalg/tests
#       copying numpy/linalg/tests/test_build.py -> build/lib.macosx-11.1-arm64-3.10/numpy/linalg/tests
#       copying numpy/linalg/tests/test_regression.py -> build/lib.macosx-11.1-arm64-3.10/numpy/linalg/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       copying numpy/ma/extras.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       copying numpy/ma/testutils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       copying numpy/ma/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       copying numpy/ma/core.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       copying numpy/ma/bench.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       copying numpy/ma/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       copying numpy/ma/timer_comparison.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       copying numpy/ma/mrecords.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       copying numpy/ma/tests/test_old_ma.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       copying numpy/ma/tests/test_core.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       copying numpy/ma/tests/test_deprecations.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       copying numpy/ma/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       copying numpy/ma/tests/test_subclassing.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       copying numpy/ma/tests/test_extras.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       copying numpy/ma/tests/test_mrecords.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       copying numpy/ma/tests/test_regression.py -> build/lib.macosx-11.1-arm64-3.10/numpy/ma/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib
#       copying numpy/matrixlib/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib
#       copying numpy/matrixlib/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib
#       copying numpy/matrixlib/defmatrix.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_matrix_linalg.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_defmatrix.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_interaction.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_numeric.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_masked_matrix.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_multiarray.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_regression.py -> build/lib.macosx-11.1-arm64-3.10/numpy/matrixlib/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/laguerre.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/_polybase.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/polyutils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/hermite_e.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/chebyshev.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/polynomial.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/legendre.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       copying numpy/polynomial/hermite.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_chebyshev.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_hermite_e.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_polynomial.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_laguerre.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_legendre.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_printing.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_hermite.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_classes.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_polyutils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/polynomial/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/random
#       copying numpy/random/_pickle.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random
#       copying numpy/random/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random
#       copying numpy/random/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_generator_mt19937.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_randomstate.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_direct.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_extending.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_smoke.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_randomstate_regression.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_seed_sequence.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_generator_mt19937_regressions.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_random.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       copying numpy/random/tests/test_regression.py -> build/lib.macosx-11.1-arm64-3.10/numpy/random/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/testing
#       copying numpy/testing/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing
#       copying numpy/testing/setup.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing
#       copying numpy/testing/utils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing
#       copying numpy/testing/print_coercion_tables.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/testing/_private
#       copying numpy/testing/_private/nosetester.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/_private
#       copying numpy/testing/_private/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/_private
#       copying numpy/testing/_private/noseclasses.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/_private
#       copying numpy/testing/_private/utils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/_private
#       copying numpy/testing/_private/parameterized.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/_private
#       copying numpy/testing/_private/decorators.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/_private
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/testing/tests
#       copying numpy/testing/tests/test_utils.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/tests
#       copying numpy/testing/tests/test_decorators.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/tests
#       copying numpy/testing/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/tests
#       copying numpy/testing/tests/test_doctesting.py -> build/lib.macosx-11.1-arm64-3.10/numpy/testing/tests
#       creating build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       copying numpy/tests/test_warnings.py -> build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       copying numpy/tests/test_matlib.py -> build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       copying numpy/tests/test_ctypeslib.py -> build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       copying numpy/tests/test_numpy_version.py -> build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       copying numpy/tests/__init__.py -> build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       copying numpy/tests/test_reloading.py -> build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       copying numpy/tests/test_public_api.py -> build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       copying numpy/tests/test_scripts.py -> build/lib.macosx-11.1-arm64-3.10/numpy/tests
#       running build_clib
#       customize UnixCCompiler
#       customize UnixCCompiler using new_build_clib
#       building 'npymath' library
#       compiling C sources
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64
#
#       creating build/temp.macosx-11.1-arm64-3.10
#       creating build/temp.macosx-11.1-arm64-3.10/numpy
#       creating build/temp.macosx-11.1-arm64-3.10/numpy/core
#       creating build/temp.macosx-11.1-arm64-3.10/numpy/core/src
#       creating build/temp.macosx-11.1-arm64-3.10/numpy/core/src/npymath
#       creating build/temp.macosx-11.1-arm64-3.10/build
#       creating build/temp.macosx-11.1-arm64-3.10/build/src.macosx-11.1-arm64-3.10
#       creating build/temp.macosx-11.1-arm64-3.10/build/src.macosx-11.1-arm64-3.10/numpy
#       creating build/temp.macosx-11.1-arm64-3.10/build/src.macosx-11.1-arm64-3.10/numpy/core
# ...
#       extern long double modfl(long double, long double *);
#                                                          ^
#       1 warning generated.
#       clang: numpy/core/src/umath/reduction.c
#       clang: numpy/core/src/multiarray/number.c
#       In file included from numpy/core/src/umath/ufunc_object.c:37:
#       In file included from numpy/core/include/numpy/ufuncobject.h:4:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       In file included from numpy/core/src/umath/reduction.c:23:
#       In file included from numpy/core/include/numpy/ufuncobject.h:4:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       1 warning generated.
#       clang: numpy/core/src/umath/ufunc_type_resolution.c
#       In file included from numpy/core/src/umath/ufunc_type_resolution.c:23:
#       In file included from numpy/core/include/numpy/ufuncobject.h:4:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       clang: build/src.macosx-11.1-arm64-3.10/numpy/core/src/npymath/ieee754.c
#       In file included from numpy/core/src/npymath/ieee754.c.src:7:
#       In file included from numpy/core/src/npymath/npy_math_common.h:9:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       1 warning generated.
#       clang: build/src.macosx-11.1-arm64-3.10/numpy/core/src/npymath/npy_math_complex.c
#       1 warning generated.
#       clang: numpy/core/src/umath/override.c
#       In file included from numpy/core/src/npymath/npy_math_complex.c.src:34:
#       In file included from numpy/core/src/npymath/npy_math_common.h:9:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       2 warnings generated.
#       clang: numpy/core/src/multiarray/flagsobject.c
#       In file included from numpy/core/src/umath/override.c:5:
#       In file included from numpy/core/include/numpy/ufuncobject.h:4:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       1 warning generated.
#       clang: numpy/core/src/npymath/halffloat.c
#       1 warning generated.
#       clang: numpy/core/src/npymath/npy_math.c
#       In file included from numpy/core/src/npymath/halffloat.c:2:
#       In file included from numpy/core/include/numpy/halffloat.h:5:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       clang: numpy/core/src/multiarray/getset.c
#       numpy/core/src/umath/loops.c.src:2611:22: warning: code will never be executed [-Wunreachable-code]
#               npy_intp n = dimensions[0];
#                            ^~~~~~~~~~clang: numpy/core/src/multiarray/nditer_api.c
#
#       numpy/core/src/umath/loops.c.src:2610:29: note: silence by adding parentheses to mark code as explicitly dead
#           if (IS_BINARY_REDUCE && 0) {
#                                   ^
#                                   /* DISABLES CODE */ ( )
#       numpy/core/src/umath/loops.c.src:2611:22: warning: code will never be executed [-Wunreachable-code]
#               npy_intp n = dimensions[0];
#                            ^~~~~~~~~~
#       numpy/core/src/umath/loops.c.src:2610:29: note: silence by adding parentheses to mark code as explicitly dead
#           if (IS_BINARY_REDUCE && 0) {
#                                   ^
#                                   /* DISABLES CODE */ ( )
#       1 warning generated.
#       clang: numpy/core/src/common/array_assign.c
#       numpy/core/src/umath/loops.c.src:2611:22: warning: code will never be executed [-Wunreachable-code]
#               npy_intp n = dimensions[0];
#                            ^~~~~~~~~~
#       numpy/core/src/umath/loops.c.src:2610:29: note: silence by adding parentheses to mark code as explicitly dead
#           if (IS_BINARY_REDUCE && 0) {
#                                   ^
#                                   /* DISABLES CODE */ ( )
#       In file included from numpy/core/src/npymath/npy_math.c:9:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       clang: numpy/core/src/common/mem_overlap.c
#       1 warning generated.
#       clang: numpy/core/src/common/ucsnarrow.c
#       In file included from numpy/core/src/common/ucsnarrow.c:11:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       clang: build/src.macosx-11.1-arm64-3.10/numpy/core/src/common/npy_cpu_features.c
#       1 warning generated.
#       clang: numpy/core/src/common/ufunc_override.c
#       1 warning generated.
#       clang: numpy/core/src/umath/extobj.c
#       clang: numpy/core/src/common/numpyos.c
#       clang: numpy/core/src/common/cblasfuncs.c
#       clang: numpy/core/src/common/npy_longdouble.c
#       In file included from numpy/core/src/umath/extobj.c:12:
#       In file included from numpy/core/include/numpy/ufuncobject.h:4:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       1 warning generated.
#       clang: build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath/scalarmath.c
#       In file included from numpy/core/src/common/numpyos.c:10:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       In file included from numpy/core/src/common/npy_longdouble.c:7:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       1 warning generated.
#       1 warning generated.
#       In file included from numpy/core/src/umath/scalarmath.c.src:16:
#       In file included from numpy/core/include/numpy/ufuncobject.h:4:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       clang: numpy/core/src/common/python_xerbla.c
#       1 warning generated.
#       1 warning generated.
#       clang: numpy/core/src/multiarray/mapping.c
#       1 warning generated.
#       clang: numpy/core/src/multiarray/methods.c
#       4 warnings generated.
#       clang: build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath/matmul.c
#       In file included from numpy/core/src/umath/matmul.c.src:12:
#       In file included from numpy/core/include/numpy/ufuncobject.h:4:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       1 warning generated.
#       clang: build/src.macosx-11.1-arm64-3.10/numpy/core/src/umath/clip.c
#       In file included from numpy/core/src/umath/clip.c.src:10:
#       In file included from numpy/core/include/numpy/halffloat.h:5:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       1 warning generated.
#       error: Command "clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DHAVE_CBLAS -Ibuild/src.macosx-11.1-arm64-3.10/numpy/core/src/umath -Ibuild/src.macosx-11.1-arm64-3.10/numpy/core/src/npymath -Ibuild/src.macosx-11.1-arm64-3.10/numpy/core/src/common -Inumpy/core/include -Ibuild/src.macosx-11.1-arm64-3.10/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/piotr/anaconda3/include/python3.10 -Ibuild/src.macosx-11.1-arm64-3.10/numpy/core/src/common -Ibuild/src.macosx-11.1-arm64-3.10/numpy/core/src/npymath -c build/src.macosx-11.1-arm64-3.10/numpy/core/src/multiarray/scalartypes.c -o build/temp.macosx-11.1-arm64-3.10/build/src.macosx-11.1-arm64-3.10/numpy/core/src/multiarray/scalartypes.o -MMD -MF build/temp.macosx-11.1-arm64-3.10/build/src.macosx-11.1-arm64-3.10/numpy/core/src/multiarray/scalartypes.o.d" failed with exit status 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects
# Collecting beautifulsoup4==4.6.3
#   Downloading beautifulsoup4-4.6.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
#       Successfully uninstalled beautifulsoup4-4.12.2
# Successfully installed beautifulsoup4-4.6.3

# %%
# To install the requirements for the entire chapter, uncomment the lines below and run this cell

# ===========================

try :
    import google.colab
    # !curl https://raw.githubusercontent.com/practical-nlp/practical-nlp/master/Ch2/ch2-requirements.txt | xargs -n 1 -L 1 pip install
except ModuleNotFoundError :
    # !pip install -r "ch2-requirements.txt"

# ===========================
# Out:
# Collecting numpy==1.19.5
#   Using cached numpy-1.19.5.zip (7.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pandas==1.1.5
#   Downloading pandas-1.1.5.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 19.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4==4.6.3 in /Users/piotr/anaconda3/lib/python3.10/site-packages (from -r ch2-requirements.txt (line 3)) (4.6.3)
# Collecting pytesseract==0.3.7
#   Downloading pytesseract-0.3.7.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting spacy==2.2.4
#   Downloading spacy-2.2.4.tar.gz (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 47.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [616 lines of output]
#       Collecting setuptools
#         Using cached setuptools-67.7.2-py3-none-any.whl (1.1 MB)
#       Collecting wheel
#         Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
#       Collecting cython>=0.25
#         Using cached Cython-0.29.34-py2.py3-none-any.whl (988 kB)
#       Collecting cymem<2.1.0,>=2.0.2
#         Downloading cymem-2.0.7-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
#       Collecting preshed<3.1.0,>=3.0.2
#         Downloading preshed-3.0.8-cp310-cp310-macosx_11_0_arm64.whl (101 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/101.5 kB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 92.2/101.5 kB 2.3 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 2.1 MB/s eta 0:00:00
#       Collecting murmurhash<1.1.0,>=0.28.0
#         Downloading murmurhash-1.0.9-cp310-cp310-macosx_11_0_arm64.whl (19 kB)
#       Collecting thinc==7.4.0
#         Downloading thinc-7.4.0.tar.gz (1.3 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.3 MB ? eta -:--:--
#            ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/1.3 MB 6.3 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 0.6/1.3 MB 8.2 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.3/1.3 MB 12.5 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.4 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting blis<0.5.0,>=0.4.0
#         Downloading blis-0.4.1.tar.gz (1.8 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 MB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 1.1/1.8 MB 36.7 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.4 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting wasabi<1.1.0,>=0.0.9
#         Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
#       Collecting srsly<1.1.0,>=0.0.6
#         Downloading srsly-1.0.6-cp310-cp310-macosx_11_0_arm64.whl (208 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/208.2 kB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.2/208.2 kB 19.9 MB/s eta 0:00:00
#       Collecting catalogue<1.1.0,>=0.0.7
#         Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
#       Collecting numpy>=1.7.0
#         Using cached numpy-1.24.3-cp310-cp310-macosx_11_0_arm64.whl (13.9 MB)
#       Collecting plac<1.2.0,>=0.9.6
#         Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
#       Collecting tqdm<5.0.0,>=4.10.0
#         Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/77.1 kB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 9.4 MB/s eta 0:00:00
#       Building wheels for collected packages: thinc, blis
#         Building wheel for thinc (setup.py): started
#         Building wheel for thinc (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [365 lines of output]
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.macosx-11.1-arm64-cpython-310
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/describe.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/misc.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/config.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/compat.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/check.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/t2v.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/about.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/_registry.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/api.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/loss.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/v2v.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/t2t.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/exceptions.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/i2v.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/rates.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/tests
#             copying thinc/tests/conftest.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests
#             copying thinc/tests/strategies.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests
#             copying thinc/tests/test_api_funcs.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests
#             copying thinc/tests/util.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests
#             copying thinc/tests/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests
#             copying thinc/tests/test_util.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests
#             copying thinc/tests/test_config.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_check_exceptions.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_model.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_hash_embed.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_beam_search.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_pickle.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_pooling.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_imports.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_rates.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_rnn.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_loss.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_linear.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_ops.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_pytorch_wrapper.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_mem.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_difference.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_affine.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_about.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_feature_extracter.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/unit
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_batch_norm.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_pickle.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_affine_learns.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_mnist.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_roundtrip_bytes.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_feed_forward.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_shape_check.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_basic_tagger.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/integration
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/linear
#             copying thinc/tests/linear/test_avgtron.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/linear
#             copying thinc/tests/linear/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/linear
#             copying thinc/tests/linear/test_sparse_array.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/linear
#             copying thinc/tests/linear/test_linear.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/tests/linear
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/vecs2vecs.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/util.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/pooling.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/vecs2vec.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/_custom_kernels.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/mem.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/vec2vec.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/train.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/_lsuv.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/load_nlp.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/hpbff.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/datasets.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/wrappers.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/visualizer.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/attention.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/convolution.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/layernorm.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/maxout.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/embed.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/batchnorm.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/difference.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/encoder_decoder.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/multiheaded_attention.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/feed_forward.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/mish.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/affine.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/feature_extracter.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/model.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/function_layer.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/resnet.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/relu.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/static_vectors.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/hash_embed.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/elu.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/rnn.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/softmax.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/selu.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural/_classes
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_datasets.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_generic_utils.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_data_utils.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/_vendorized
#             creating build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/wrapt
#             copying thinc/extra/wrapt/importer.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/wrapt
#             copying thinc/extra/wrapt/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/wrapt
#             copying thinc/extra/wrapt/wrappers.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/wrapt
#             copying thinc/extra/wrapt/decorators.py -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra/wrapt
#             copying thinc/structs.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/typedefs.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/linalg.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/linalg.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/typedefs.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/__init__.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/structs.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/cpu.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/compile_time_constants.pxi -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/typedefs.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/linalg.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/structs.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc
#             copying thinc/linear/sparse.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/features.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/avgtron.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/serialize.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/linear.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/serialize.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/__init__.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/avgtron.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/features.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/sparse.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/serialize.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/linear.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/avgtron.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/features.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/linear/sparse.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/linear
#             copying thinc/neural/_aligned_alloc.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/optimizers.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/ops.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/ops.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/__init__.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/cpu.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/optimizers.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/ops.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/_aligned_alloc.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/_custom_kernels.cu -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/neural/_murmur3.cu -> build/lib.macosx-11.1-arm64-cpython-310/thinc/neural
#             copying thinc/extra/mb.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/search.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/cache.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/eg.pyx -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/__init__.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/eg.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/cache.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/search.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/mb.pxd -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/eg.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/cache.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/search.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             copying thinc/extra/mb.cpp -> build/lib.macosx-11.1-arm64-cpython-310/thinc/extra
#             running build_ext
#             building 'thinc.linalg' extension
#             creating build/temp.macosx-11.1-arm64-cpython-310
#             creating build/temp.macosx-11.1-arm64-cpython-310/thinc
#             clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -I/Users/piotr/anaconda3/include/python3.10 -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/thinc_f2cd94972d324f87a447de7ef028410e/include -I/Users/piotr/anaconda3/include/python3.10 -c thinc/linalg.cpp -o build/temp.macosx-11.1-arm64-cpython-310/thinc/linalg.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/piotr/anaconda3/lib -L/Users/piotr/anaconda3/lib -Wl,-rpath,/Users/piotr/anaconda3/lib -L/Users/piotr/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-310/thinc/linalg.o -o build/lib.macosx-11.1-arm64-cpython-310/thinc/linalg.cpython-310-darwin.so
#             building 'thinc.structs' extension
#             clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -I/Users/piotr/anaconda3/include/python3.10 -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/thinc_f2cd94972d324f87a447de7ef028410e/include -I/Users/piotr/anaconda3/include/python3.10 -c thinc/structs.cpp -o build/temp.macosx-11.1-arm64-cpython-310/thinc/structs.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/piotr/anaconda3/lib -L/Users/piotr/anaconda3/lib -Wl,-rpath,/Users/piotr/anaconda3/lib -L/Users/piotr/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-310/thinc/structs.o -o build/lib.macosx-11.1-arm64-cpython-310/thinc/structs.cpython-310-darwin.so
#             building 'thinc.typedefs' extension
#             clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -I/Users/piotr/anaconda3/include/python3.10 -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/thinc_f2cd94972d324f87a447de7ef028410e/include -I/Users/piotr/anaconda3/include/python3.10 -c thinc/typedefs.cpp -o build/temp.macosx-11.1-arm64-cpython-310/thinc/typedefs.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/piotr/anaconda3/lib -L/Users/piotr/anaconda3/lib -Wl,-rpath,/Users/piotr/anaconda3/lib -L/Users/piotr/anaconda3/lib build/temp.macosx-11.1-arm64-cpython-310/thinc/typedefs.o -o build/lib.macosx-11.1-arm64-cpython-310/thinc/typedefs.cpython-310-darwin.so
#             building 'thinc.linear.avgtron' extension
#             creating build/temp.macosx-11.1-arm64-cpython-310/thinc/linear
#             clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/piotr/anaconda3/include -arch arm64 -I/Users/piotr/anaconda3/include/python3.10 -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/thinc_f2cd94972d324f87a447de7ef028410e/include -I/Users/piotr/anaconda3/include/python3.10 -c thinc/linear/avgtron.cpp -o build/temp.macosx-11.1-arm64-cpython-310/thinc/linear/avgtron.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             thinc/linear/avgtron.cpp:13611:13: warning: code will never be executed [-Wunreachable-code]
#               __pyx_r = 0;
#                         ^
#             thinc/linear/avgtron.cpp:14044:5: error: expression is not assignable
#                 ++Py_REFCNT(o);
#                 ^ ~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:14046:5: error: expression is not assignable
#                 --Py_REFCNT(o);
#                 ^ ~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:22: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                                 (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                  ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#                   PyUnicode_WSTR_LENGTH(op) :                    \
#                   ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#             #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                               ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3)
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15133:22: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                                 (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                  ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#                   ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                          ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15133:22: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                                 (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                  ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#                    PyUnicode_WSTR_LENGTH(op)))
#                    ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#             #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                               ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3)
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15133:52: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                                 (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#                   PyUnicode_WSTR_LENGTH(op) :                    \
#                   ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#             #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                               ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3)
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15133:52: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                                 (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#                   ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                          ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15133:52: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                                 (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#                    PyUnicode_WSTR_LENGTH(op)))
#                    ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#             #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                               ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3)
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15149:26: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                                     (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                      ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#                   PyUnicode_WSTR_LENGTH(op) :                    \
#                   ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#             #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                               ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3)
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15149:26: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                                     (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                      ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#                   ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                          ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15149:26: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                                     (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                      ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#                    PyUnicode_WSTR_LENGTH(op)))
#                    ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#             #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                               ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3)
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15149:59: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                                     (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                       ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#                   PyUnicode_WSTR_LENGTH(op) :                    \
#                   ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#             #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                               ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3)
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15149:59: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                                     (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                       ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#                   ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                          ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             thinc/linear/avgtron.cpp:15149:59: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                                     (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                       ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#                    PyUnicode_WSTR_LENGTH(op)))
#                    ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#             #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                               ^
#             /Users/piotr/anaconda3/include/python3.10/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#             Py_DEPRECATED(3.3)
#             ^
#             /Users/piotr/anaconda3/include/python3.10/pyport.h:513:54: note: expanded from macro 'Py_DEPRECATED'
#             #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                                  ^
#             13 warnings and 2 errors generated.
#             error: command '/usr/bin/clang' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for thinc
#         Running setup.py clean for thinc
#         Building wheel for blis (setup.py): started
#         Building wheel for blis (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [78 lines of output]
#             BLIS_COMPILER? None
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.macosx-11.1-arm64-cpython-310
#             creating build/lib.macosx-11.1-arm64-cpython-310/blis
#             copying blis/benchmark.py -> build/lib.macosx-11.1-arm64-cpython-310/blis
#             copying blis/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/blis
#             copying blis/about.py -> build/lib.macosx-11.1-arm64-cpython-310/blis
#             creating build/lib.macosx-11.1-arm64-cpython-310/blis/tests
#             copying blis/tests/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/blis/tests
#             copying blis/tests/test_dotv.py -> build/lib.macosx-11.1-arm64-cpython-310/blis/tests
#             copying blis/tests/test_gemm.py -> build/lib.macosx-11.1-arm64-cpython-310/blis/tests
#             copying blis/tests/common.py -> build/lib.macosx-11.1-arm64-cpython-310/blis/tests
#             copying blis/cy.pyx -> build/lib.macosx-11.1-arm64-cpython-310/blis
#             copying blis/py.pyx -> build/lib.macosx-11.1-arm64-cpython-310/blis
#             copying blis/__init__.pxd -> build/lib.macosx-11.1-arm64-cpython-310/blis
#             copying blis/cy.pxd -> build/lib.macosx-11.1-arm64-cpython-310/blis
#             running build_ext
#             unix
#             py_compiler gcc
#             {'TRAVIS_ARCH': 'amd64', 'rvm_bin_path': '/Users/travis/.rvm/bin', 'NVM_CD_FLAGS': '', 'GEM_HOME': '/Users/travis/.rvm/gems/ruby-2.4.3', 'HAS_JOSH_K_SEAL_OF_APPROVAL': 'true', 'SHELL': '/bin/bash', 'TERM': 'xterm', 'TRAVIS_TEST_RESULT': '', 'PYTHON_EXE': '/Users/travis/build/explosion/cython-blis/venv/bin/python', 'TMPDIR': '/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/', 'IRBRC': '/Users/travis/.rvm/rubies/ruby-2.4.3/.irbrc', 'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.KSqzJVi3Ll/Render', 'TRAVIS_COMMIT': '2435bb60768369ae2d5b4b056bc12a80333f6658', 'TRAVIS_APT_PROXY': 'http://build-cache.travisci.net', 'TRAVIS_OS_NAME': 'osx', 'TRAVIS_JOB_NAME': '', 'OLDPWD': '/Users/travis/build/explosion/cython-blis', 'TRAVIS_INTERNAL_RUBY_REGEX': '^ruby-(2\\.[0-4]\\.[0-9]|1\\.9\\.3)', 'MY_RUBY_HOME': '/Users/travis/.rvm/rubies/ruby-2.4.3', 'TRAVIS_ROOT': '/', 'LC_ALL': 'en_US.UTF-8', 'TRAVIS_TIMER_ID': '367ffaac', 'USER': 'travis', 'NVM_DIR': '/Users/travis/.nvm', 'ANSI_GREEN': '\\033', '_system_type': 'Darwin', 'TRAVIS_INFRA': 'macstadium', 'TRAVIS_LANGUAGE': 'generic', 'rvm_path': '/Users/travis/.rvm', 'ANSI_RESET': '\\033', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.TiElbGqhQ7/Listeners', 'TRAVIS_DIST': 'notset', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', 'TRAVIS': 'true', 'ANSI_YELLOW': '\\033', 'TRAVIS_REPO_SLUG': 'explosion/cython-blis', 'PAGER': 'cat', 'TRAVIS_PULL_REQUEST': 'false', 'TRAVIS_COMMIT_MESSAGE': 'Try to fix travis export', 'TRAVIS_BUILD_STAGE_NAME': '', 'VIRTUAL_ENV': '/Users/travis/build/explosion/cython-blis/venv', 'TRAVIS_CMD': 'if [[ "$TRAVIS_OS_NAME" == "osx" ]]; then ./bin/generate-make-jsonl darwin x86_64 --export; fi', 'rvm_prefix': '/Users/travis', 'PATH': '/Users/travis/build/explosion/cython-blis/venv/bin:/Users/travis/.rvm/gems/ruby-2.4.3/bin:/Users/travis/.rvm/gems/ruby-2.4.3@global/bin:/Users/travis/.rvm/rubies/ruby-2.4.3/bin:/Users/travis/.rvm/bin:/Users/travis/bin:/Users/travis/.local/bin:/Users/travis/.nvm/versions/node/v6.14.3/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin', 'TRAVIS_TMPDIR': '/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/tmp.dYZ1JSlR', 'TRAVIS_JOB_WEB_URL': 'https://travis-ci.org/explosion/cython-blis/jobs/506249336', 'TRAVIS_OSX_IMAGE': '', 'TRAVIS_PULL_REQUEST_SHA': '', 'TRAVIS_BUILD_WEB_URL': 'https://travis-ci.org/explosion/cython-blis/builds/506249333', 'UNICODE_WIDTH': '32', 'PWD': '/Users/travis/build/explosion/cython-blis/flame-blis', 'CONTINUOUS_INTEGRATION': 'true', 'LANG': 'en_US.UTF-8', 'XPC_FLAGS': '0x0', '_system_arch': 'x86_64', 'TRAVIS_ENABLE_INFRA_DETECTION': 'true', '_system_version': '10.13', 'TRAVIS_SUDO': 'true', 'TRAVIS_ALLOW_FAILURE': 'false', 'TRAVIS_TAG': '', 'XPC_SERVICE_NAME': '0', 'TRAVIS_HOME': '/Users/travis', 'MB_PYTHON_VERSION': '3.6', 'CXX': 'clang++', 'rvm_version': '1.29.3 (latest)', 'TRAVIS_INIT': 'notset', 'HOME': '/Users/travis', 'PS4': '+', 'SHLVL': '2', 'rvm_pretty_print_flag': 'auto', 'TRAVIS_EVENT_TYPE': 'push', 'TRAVIS_JOB_NUMBER': '511.3', 'ANSI_CLEAR': '\\033[0K', 'CI': 'true', 'TRAVIS_TIMER_START_TIME': '1552568307662747000', 'TRAVIS_BUILD_ID': '506249333', 'LOGNAME': 'travis', 'MACOSX_DEPLOYMENT_TARGET': '10.7', 'GEM_PATH': '/Users/travis/.rvm/gems/ruby-2.4.3:/Users/travis/.rvm/gems/ruby-2.4.3@global', 'TRAVIS_PULL_REQUEST_SLUG': '', 'DEBIAN_FRONTEND': 'noninteractive', 'TRAVIS_SECURE_ENV_VARS': 'false', 'PIP_CMD': '/Users/travis/build/explosion/cython-blis/venv/bin/pip', 'NVM_BIN': '/Users/travis/.nvm/versions/node/v6.14.3/bin', 'TRAVIS_APP_HOST': 'build.travis-ci.org', 'GIT_ASKPASS': 'echo', 'DISPLAY': '/private/tmp/com.apple.launchd.uF8XjeYY64/org.macosforge.xquartz:0', 'TRAVIS_BRANCH': 'update-blis', 'CC': 'clang', 'TRAVIS_COMMIT_RANGE': '9aa6c2ee9c3b...2435bb607683', 'PLAT': 'x86_64', 'TRAVIS_PULL_REQUEST_BRANCH': '', 'RUBY_VERSION': 'ruby-2.4.3', 'ANSI_RED': '\\033', 'TRAVIS_JOB_ID': '506249336', 'TRAVIS_BUILD_DIR': '/Users/travis/build/explosion/cython-blis', '_system_name': ...
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/bulldozer/bli_cntx_init_bulldozer.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpq3qrewid/bli_cntx_init_bulldozer.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/excavator/bli_cntx_init_excavator.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpq3qrewid/bli_cntx_init_excavator.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/generic/bli_cntx_init_generic.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpq3qrewid/bli_cntx_init_generic.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
# ...
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/bulldozer/bli_cntx_init_bulldozer.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_bulldozer.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/excavator/bli_cntx_init_excavator.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_excavator.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/generic/bli_cntx_init_generic.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_generic.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/haswell/bli_cntx_init_haswell.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_haswell.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/penryn/bli_cntx_init_penryn.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_penryn.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/piledriver/bli_cntx_init_piledriver.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_piledriver.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/sandybridge/bli_cntx_init_sandybridge.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_sandybridge.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/steamroller/bli_cntx_init_steamroller.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_steamroller.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/config/zen/bli_cntx_init_zen.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_cntx_init_zen.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/kernels/sandybridge/3/bli_gemm_sandybridge_asm_d8x4.c -o /var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_gemm_sandybridge_asm_d8x4.o -O3 -mavx -mfpmath=sse -march=corei7-avx -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64
#             clang: error: the clang compiler does not support '-march=corei7-avx'
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 34, in <module>
#               File "/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/setup.py", line 239, in <module>
#                 setup(
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#                 return distutils.core.setup(**attrs)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#                 return run_commands(dist)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#                 dist.run_commands()
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#                 self.run_command(cmd)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#                 super().run_command(command)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#                 cmd_obj.run()
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/command/install.py", line 68, in run
#                 return orig.install.run(self)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/install.py", line 698, in run
#                 self.run_command('build')
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#                 self.distribution.run_command(command)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#                 super().run_command(command)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#                 cmd_obj.run()
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#                 self.run_command(cmd_name)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#                 self.distribution.run_command(command)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#                 super().run_command(command)
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#                 cmd_obj.run()
#               File "/Users/piotr/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 346, in run
#                 self.build_extensions()
#               File "/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/setup.py", line 103, in build_extensions
#                 objects = self.compile_objects(compiler.split("-")[0], arch, OBJ_DIR)
#               File "/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/setup.py", line 188, in compile_objects
#                 objects.append(self.build_object(env=env, **spec))
#               File "/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/setup.py", line 201, in build_object
#                 subprocess.check_call(command, cwd=BLIS_DIR)
#               File "/Users/piotr/anaconda3/lib/python3.10/subprocess.py", line 369, in check_call
#                 raise CalledProcessError(retcode, cmd)
#             subprocess.CalledProcessError: Command '['clang', '-c', '/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/kernels/sandybridge/3/bli_gemm_sandybridge_asm_d8x4.c', '-o', '/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/tmpsz7ayi_e/bli_gemm_sandybridge_asm_d8x4.o', '-O3', '-mavx', '-mfpmath=sse', '-march=corei7-avx', '-fPIC', '-std=c99', '-D_POSIX_C_SOURCE=200112L', '-DBLIS_VERSION_STRING="0.5.1"', '-DBLIS_IS_BUILDING_LIBRARY', '-Iinclude/darwin-x86_64', '-I./frame/3/', '-I./frame/ind/ukernels/', '-I./frame/1m/', '-I./frame/1f/', '-I./frame/1/', '-I./frame/include', '-I/private/var/folders/7k/5cn3qjmd02qbrvy6k109rg200000gn/T/pip-install-ur5h_t_k/blis_fbde54c8f09e47778abad63966a5f08f/blis/_src/include/darwin-x86_64']' returned non-zero exit status 1.
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: legacy-install-failure
#
#       × Encountered error while trying to install package.
#       ╰─> blis
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for output from the failure.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# making the necessary imports
from pprint import pprint
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
myurl = "https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" # specify the url
html = urlopen(myurl).read() # query the website so that it returns a html page  
soupified = BeautifulSoup(html, 'html.parser') # parse the html in the 'html' variable, and store it in Beautiful Soup format

# %% [markdown]
# As the size of the HTML webpage (soupified) is large, we are just showing some of its output (only 2000 characters).

# %%
#pprint(soupified.prettify())      # for printing the full HTML structure of the webpage

# %%
pprint(soupified.prettify()[:2000]) # to get an idea of the html structure of the webpage
# Out:
# ('<!DOCTYPE html>\n'
#  '<html class="html__responsive " itemscope="" '
#  'itemtype="https://schema.org/QAPage" lang="en">\n'
#  ' <head>\n'
#  '  <title>\n'
#  '   python - How do I get the current time? - Stack Overflow\n'
#  '  </title>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" '
#  'rel="shortcut icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="apple-touch-icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="image_src"/>\n'
#  '  <link href="/opensearch.xml" rel="search" title="Stack Overflow" '
#  'type="application/opensearchdescription+xml"/>\n'
#  '  <link '
#  'href="https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time" '
#  'rel="canonical">\n'
#  '   <meta content="width=device-width, height=device-height, '
#  'initial-scale=1.0, minimum-scale=1.0" name="viewport"/>\n'
#  '   <meta content="website" property="og:type">\n'
#  '    <meta '
#  'content="https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time" '
#  'property="og:url"/>\n'
#  '    <meta content="Stack Overflow" property="og:site_name"/>\n'
#  '    <meta '
#  'content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" '
#  'itemprop="image primaryImageOfPage" property="og:image"/>\n'
#  '    <meta content="summary" name="twitter:card"/>\n'
#  '    <meta content="stackoverflow.com" name="twitter:domain"/>\n'
#  '    <meta content="How do I get the current time?" itemprop="name" '
#  'name="twitter:title" property="og:title"/>\n'
#  '    <meta content="How do I get the current time?" itemprop="description" '
#  'name="twitter:description" property="og:description"/>\n'
#  '    <script id="webpack-public-path" type="text/uri-list">\n'
#  '     https://cdn.sstatic.net/\n'
#  '    </script>\n'
#  '    <script '
#  'src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js">\n'
#  '    </script>\n'
#  '    <script defer="" '
#  'src="https://cdn.sstatic.net/Js/third-party/npm/@stackoverflow/stacks/dist/js/stacks.min.js?v=b95611219aa3">\n'
#  '    </script>\n'
#  '    <script src="https://cdn.sst')

# %%
soupified.title # to get the title of the web page
# Out:
# <title>python - How do I get the current time? - Stack Overflow</title>

# %%
question = soupified.find("div", {"class": "question"}) # find the nevessary tag and class which it belongs to
questiontext = question.find("div", {"class": "s-prose js-post-body"})
print("Question: \n", questiontext.get_text().strip())

answer = soupified.find("div", {"class": "answer"}) # find the nevessary tag and class which it belongs to
answertext = answer.find("div", {"class": "s-prose js-post-body"})
print("Best answer: \n", answertext.get_text().strip())
# Out:
# Question:
#  How do I get the current time?
# Best answer:
#  Use datetime:
# >>> import datetime
# >>> now = datetime.datetime.now()
# >>> now
# datetime.datetime(2009, 1, 6, 15, 8, 24, 78915)
# >>> print(now)
# 2009-01-06 15:08:24.789150
#
# For just the clock time without the date:
# >>> now.time()
# datetime.time(15, 8, 24, 78915)
# >>> print(now.time())
# 15:08:24.789150
#
#
# To save typing, you can import the datetime object from the datetime module:
# >>> from datetime import datetime
#
# Then remove the prefix datetime. from all of the above.

# %% [markdown]
# BeautifulSoup is one of the many libraries which allow us to scrape web pages. Depending on your needs you can choose between the many available choices like beautifulsoup, scrapy, selenium, etc

# %%
mySimpleTex = 'Oh my oh my ❗️🏧'
mySimpleTextEnc = mySimpleTex.encode("utf-8")
print(mySimpleTextEnc)
# Out:
# b'Oh my oh my \xe2\x9d\x97\xef\xb8\x8f\xf0\x9f\x8f\xa7'
